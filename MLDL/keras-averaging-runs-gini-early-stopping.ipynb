# %% [markdown]
# # 신경망 모델

# %% [markdown]
# ## import libraries

# %%
import numpy as np
np.random.seed()
import pandas as pd
from datetime import datetime
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler

from keras.models import load_model
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger, Callback
from keras.wrappers.scikit_learn import KerasClassifier
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## ComputeGini callback
# - ROC_AUC계산 후 gini를 구하고
# - parameter의 log를 생성하여 early stopping에 사용

# %%
class roc_auc_callback(Callback):
    def __init__(self,training_data,validation_data):
        self.x = training_data[0]
        self.y = training_data[1]
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        y_pred = self.model.predict_proba(self.x, verbose=0)
        roc = roc_auc_score(self.y, y_pred)
        logs['roc_auc'] = roc_auc_score(self.y, y_pred)
        logs['norm_gini'] = ( roc_auc_score(self.y, y_pred) * 2 ) - 1

        y_pred_val = self.model.predict_proba(self.x_val, verbose=0)
        roc_val = roc_auc_score(self.y_val, y_pred_val)
        logs['roc_auc_val'] = roc_auc_score(self.y_val, y_pred_val)
        logs['norm_gini_val'] = ( roc_auc_score(self.y_val, y_pred_val) * 2 ) - 1

        print('\rroc_auc: %s - roc_auc_val: %s - norm_gini: %s - norm_gini_val: %s' % (str(round(roc,5)),str(round(roc_val,5)),str(round((roc*2-1),5)),str(round((roc_val*2-1),5))), end=10*' '+'\n')
        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %% [markdown]
# ## Housekeeping utilities
# - Timer
# - data scale

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod(
            (datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' %
              (thour, tmin, round(tsec, 2)))

def scale_data(X, scaler=None):
    if not scaler:
        scaler = MinMaxScaler(feature_range=(-1, 1))
        scaler.fit(X)
    X = scaler.transform(X)
    return X, scaler

# %% [markdown]
# ## Load dataset

# %%
# train and test data path
DATA_TRAIN_PATH = './porto/train.csv'
DATA_TEST_PATH = './porto/test.csv'

def load_data(path_train=DATA_TRAIN_PATH, path_test=DATA_TEST_PATH):
    train_loader = pd.read_csv(path_train, dtype={'target': np.int8, 'id': np.int32})
    train = train_loader.drop(['target', 'id'], axis=1)
    train_labels = train_loader['target'].values
    train_ids = train_loader['id'].values
    print('\n Shape of raw train data:', train.shape)

    test_loader = pd.read_csv(path_test, dtype={'id': np.int32})
    test = test_loader.drop(['id'], axis=1)
    test_ids = test_loader['id'].values
    print(' Shape of raw test data:', test.shape)

    return train, train_labels, test, train_ids, test_ids

# %% [markdown]
# You can ignore most of the parameters below other than the top two. Obviously, more folds means longer running time, but I can tell you from experience that 10 folds with Keras will usually do better than 4. The number of "runs" should be in the 3-5 range. At a minimum, I suggest 5 folds and 3 independent runs per fold (which will eventually get averaged).  This is because of stochastic nature of neural networks, so one run per fold may or may not produce the best possible result.
#
# **If you can afford it, 10 folds and 5 runs per fold would be my recommendation. Be warned that it may take a day or two, even if you have a GPU.**

# %% [markdown]
# ## Cross Validation
# ![](./porto/k_fold.png)
# - 10 fold cross validation 사용
# - 각 fold 마다 5번의 run을 한다, 신경망은 확률적인 특성을 갖기 때문.

# %%
folds = 4
runs = 2

cv_LL = 0
cv_AUC = 0
cv_gini = 0
fpred = []
avpred = []
avreal = []
avids = []

# %% [markdown]
# Loading data. Converting "categorical" variables, even though in this dataset they are actually numeric.

# %% [markdown]
# ## Dummify categorical data

# %%
# Load data set and target values
train, target, test, tr_ids, te_ids = load_data()
n_train = train.shape[0]
train_test = pd.concat((train, test)).reset_index(drop=True)
col_to_drop = train.columns[train.columns.str.endswith('_cat')]
col_to_dummify = train.columns[train.columns.str.endswith('_cat')].astype(str).tolist()

for col in col_to_dummify:
    dummy = pd.get_dummies(train_test[col].astype('category'))
    columns = dummy.columns.astype(str).tolist()
    columns = [col + '_' + w for w in columns]
    dummy.columns = columns
    train_test = pd.concat((train_test, dummy), axis=1)

train_test.drop(col_to_dummify, axis=1, inplace=True)
# 데이터 스케일
train_test_scaled, scaler = scale_data(train_test)
train = train_test_scaled[:n_train, :]
test = train_test_scaled[n_train:, :]
print('\n Shape of processed train data:', train.shape)
print(' Shape of processed test data:', test.shape)
# Out:
#  Shape of raw train data: (595212, 57)
#  Shape of raw test data: (892816, 57)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Shape of processed train data: (595212, 227)
#  Shape of processed test data: (892816, 227)

# %% [markdown]
# ## Early Stopping
# https://kevinthegrey.tistory.com/110
# ![](./porto/early_stopping.png)

# %% [markdown]
# The two parameters below are worth playing with. Larger patience gives the network a better chance to find solutions when it gets close to the local/global minimum. It also means longer training times. Batch size is one of those parameters that can always be optimized for any given dataset. If you have a GPU, larger batch sizes translate to faster training, but that may or may not be better for the quality of training.
#
# - patience : 개선이 없다고 바로 종료하지 않고 개선이 없는 에포크를 얼마나 기다려 줄 것인 가를 지정합니다. 만약 10이라고 지정하면 개선이 없는 에포크가 10번째 지속될 경우 학습일 종료합니다.

# %%
patience = 10
batchsize = 128

# %% [markdown]
# ## 신경망 구현 순서
# Keras 를 사용하면 다음과 같은 순서로 신경망을 구성할 수 있다.
#
# 1. Sequential 모형 클래스 객체 생성
# 2. add 메서드로 레이어 추가.
#     - 입력단부터 순차적으로 추가한다.
#     - 레이어는 출력 뉴런 갯수를 첫번째 인수로 받는다.
#     - 최초의 레이어는 input_dim 인수로 입력 크기를 설정해야 한다.
#     - activation 인수로 활성화함수 설정
# 3. compile 메서드로 모형 완성.
#     - loss인수로 비용함수 설정
#     - optimizer 인수로 최적화 알고리즘 설정
#     - metrics 인수로 트레이닝 단계에서 기록할 성능 기준 설정
# 4. fit 메서드로 트레이닝
#     - nb_epoch 로 에포크(epoch) 횟수 설정
#     - batch_size 로 배치크기(batch size) 설정
#     - verbose는 학습 중 출력되는 문구를 설정하는 것으로, 주피터노트북(Jupyter Notebook)을 사용할 때는 verbose=2로 설정하여 진행 막대(progress bar)가 나오지 않도록 설정한다.

# %%
# Let's split the data into folds. I always use the same random number for reproducibility, 
# and suggest that you do the same (you certainly don't have to use 1001).
# 지정한 fold 수(=10)개 로 split 한다

skf = StratifiedKFold(n_splits=folds, random_state=1001)
starttime = timer(None)
for i, (train_index, test_index) in enumerate(skf.split(train, target)):
    start_time = timer(None)
    X_train, X_val = train[train_index], train[test_index]
    y_train, y_val = target[train_index], target[test_index]
    train_ids, val_ids = tr_ids[train_index], tr_ids[test_index]

    # This definition must be within the for loop or else it will continue training previous model
    # fold 마다 정의해주어야 함. 안그러면 이전 fold 학습한다.
    def baseline_model():
        model = Sequential()
        model.add(
            Dense(
                200, #뉴런 수
                input_dim=X_train.shape[1], #입력 크기, 최초의 레이어는 입력해주어야 함
                kernel_initializer='glorot_normal', ## Xavier initialization, weight를 초기화한다.
                ))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))
        model.add(Dense(100, kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))
        model.add(Dense(50, kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.15))
        model.add(Dense(25, kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.1))
        model.add(Dense(1, activation='sigmoid'))

        # Compile model
        model.compile(optimizer='adam', metrics = ['accuracy'], loss='binary_crossentropy')

        return model

# This is where we repeat the runs for each fold. If you choose runs=1 above, it will run a 
# regular N-fold procedure.
# 각 fold마다 학습을 반복한다. runs= 1 이면 일반적인 k fold
#########
# It is important to leave the call to random seed here, so each run starts with a different seed.
#########

    for run in range(runs):
        print('\n Fold %d - Run %d\n' % ((i + 1), (run + 1)))
        np.random.seed()

# Lots to unpack here.

# The first callback prints out roc_auc and gini values at the end of each epoch. It must be listed 
# before the EarlyStopping callback, which monitors gini values saved in the previous callback. Make 
# sure to set the mode to "max" because the default value ("auto") will not handle gini properly 
# (it will act as if the model is not improving even when roc/gini go up).

# CSVLogger creates a record of all iterations. Not really needed but it doesn't hurt to have it.

# ModelCheckpoint saves a model each time gini improves. Its mode also must be set to "max" for reasons 
# explained above.

        callbacks = [
            # 위에서 정의했던 콜백 함수
            roc_auc_callback(training_data=(X_train, y_train),validation_data=(X_val, y_val)),  # call this before EarlyStopping
            # 지니계수 earlystopping, mode=max로 설정해야 최대 지니계수를 구한다.
            EarlyStopping(monitor='norm_gini_val', patience=patience, mode='max', verbose=1),
            CSVLogger('keras-5fold-run-01-v1-epochs.log', separator=',', append=False),
            ModelCheckpoint(
                    'keras-5fold-run-01-v1-fold-' + str('%02d' % (i + 1)) + '-run-' + str('%02d' % (run + 1)) + '.check',
                    monitor='norm_gini_val', mode='max', # mode must be set to max or Keras will be confused
                    save_best_only=True,
                    verbose=1)
        ]

# The classifier is defined here. Epochs should be be set to a very large number (not 3 like below) which 
# will never be reached anyway because of early stopping. I usually put 5000 there. Because why not.

        nnet = KerasClassifier(
            # 위에 정의했던 신경망 모델
            build_fn=baseline_model,
# Epoch needs to be set to a very large number ; early stopping will prevent it from reaching
            #어짜피 earlystopping 하니까 에폭은 그냥 큰 수 넣어라
            #콜백 함수는 에폭마다 매번 호출된다.
            epochs=5000,
#             epochs=3,
            batch_size=batchsize,
            validation_data=(X_val, y_val),
            verbose=2,
            shuffle=True,
            callbacks=callbacks)

        fit = nnet.fit(X_train, y_train)
        
# We want the best saved model - not the last one where the training stopped. So we delete the old 
# model instance and load the model from the last saved checkpoint. Next we predict values both for 
# validation and test data, and create a summary of parameters for each run.

        # 한 run이 끝나면 해당 run에서 가장 성능 좋은 모델 불러온 후 predict
        del nnet
        nnet = load_model('keras-5fold-run-01-v1-fold-' + str('%02d' % (i + 1)) + '-run-' + str('%02d' % (run + 1)) + '.check')
        scores_val_run = nnet.predict_proba(X_val, verbose=0)
        LL_run = log_loss(y_val, scores_val_run)
        print('\n Fold %d Run %d Log-loss: %.5f' % ((i + 1), (run + 1), LL_run))
        AUC_run = roc_auc_score(y_val, scores_val_run)
        print(' Fold %d Run %d AUC: %.5f' % ((i + 1), (run + 1), AUC_run))
        print(' Fold %d Run %d normalized gini: %.5f' % ((i + 1), (run + 1), AUC_run*2-1))
        y_pred_run = nnet.predict_proba(test, verbose=0)
        if run > 0:
            scores_val = scores_val + scores_val_run
            y_pred = y_pred + y_pred_run
        else:
            scores_val = scores_val_run
            y_pred = y_pred_run
            
# We average all runs from the same fold and provide a parameter summary for each fold. Unless something 
# is wrong, the numbers printed here should be better than any of the individual runs.

    # 한 fold 끝나고 fold의 run값 평균
    scores_val = scores_val / runs
    y_pred = y_pred / runs
    LL = log_loss(y_val, scores_val)
    print('\n Fold %d Log-loss: %.5f' % ((i + 1), LL))
    AUC = roc_auc_score(y_val, scores_val)
    print(' Fold %d AUC: %.5f' % ((i + 1), AUC))
    print(' Fold %d normalized gini: %.5f' % ((i + 1), AUC*2-1))
    timer(start_time)
    
# We add up predictions on the test data for each fold. Create out-of-fold predictions for validation data.

    if i > 0:
        fpred = pred + y_pred
        avreal = np.concatenate((avreal, y_val), axis=0)
        avpred = np.concatenate((avpred, scores_val), axis=0)
        avids = np.concatenate((avids, val_ids), axis=0)
    else:
        fpred = y_pred
        avreal = y_val
        avpred = scores_val
        avids = val_ids
    pred = fpred
    cv_LL = cv_LL + LL
    cv_AUC = cv_AUC + AUC
    cv_gini = cv_gini + (AUC*2-1)
# Out:
#  Fold 1 - Run 1
#
# Train on 446408 samples, validate on 148804 samples
# Epoch 1/5000
#  - 41s - loss: 0.1843 - acc: 0.9521 - val_loss: 0.1533 - val_acc: 0.9635
# roc_auc: 0.62553 - roc_auc_val: 0.62007 - norm_gini: 0.25106 - norm_gini_val: 0.24014
#
# Epoch 00001: norm_gini_val improved from -inf to 0.24014, saving model to keras-5fold-run-01-v1-fold-01-run-01.check
# Epoch 2/5000
#  - 38s - loss: 0.1548 - acc: 0.9635 - val_loss: 0.1530 - val_acc: 0.9635
# roc_auc: 0.63092 - roc_auc_val: 0.6249 - norm_gini: 0.26184 - norm_gini_val: 0.24981
#
# Epoch 00002: norm_gini_val improved from 0.24014 to 0.24981, saving model to keras-5fold-run-01-v1-fold-01-run-01.check
# Epoch 3/5000
#  - 40s - loss: 0.1539 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.63478 - roc_auc_val: 0.63046 - norm_gini: 0.26956 - norm_gini_val: 0.26092
#
# Epoch 00003: norm_gini_val improved from 0.24981 to 0.26092, saving model to keras-5fold-run-01-v1-fold-01-run-01.check
# Epoch 4/5000
#  - 40s - loss: 0.1535 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9635
# roc_auc: 0.63826 - roc_auc_val: 0.63127 - norm_gini: 0.27651 - norm_gini_val: 0.26254
#
# Epoch 00004: norm_gini_val improved from 0.26092 to 0.26254, saving model to keras-5fold-run-01-v1-fold-01-run-01.check
# Epoch 5/5000
#  - 39s - loss: 0.1533 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.63708 - roc_auc_val: 0.63091 - norm_gini: 0.27415 - norm_gini_val: 0.26181
#
# Epoch 00005: norm_gini_val did not improve from 0.26254
# Epoch 6/5000
#  - 39s - loss: 0.1531 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64037 - roc_auc_val: 0.63382 - norm_gini: 0.28074 - norm_gini_val: 0.26763
#
# Epoch 00006: norm_gini_val improved from 0.26254 to 0.26763, saving model to keras-5fold-run-01-v1-fold-01-run-01.check
# Epoch 7/5000
#  - 39s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.6413 - roc_auc_val: 0.63188 - norm_gini: 0.28261 - norm_gini_val: 0.26376
#
# Epoch 00007: norm_gini_val did not improve from 0.26763
# Epoch 8/5000
#  - 40s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.64333 - roc_auc_val: 0.63286 - norm_gini: 0.28666 - norm_gini_val: 0.26572
#
# Epoch 00008: norm_gini_val did not improve from 0.26763
# Epoch 9/5000
#  - 39s - loss: 0.1528 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.64585 - roc_auc_val: 0.63314 - norm_gini: 0.29171 - norm_gini_val: 0.26628
#
# Epoch 00009: norm_gini_val did not improve from 0.26763
# Epoch 10/5000
#  - 39s - loss: 0.1526 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.64627 - roc_auc_val: 0.63269 - norm_gini: 0.29255 - norm_gini_val: 0.26539
#
# Epoch 00010: norm_gini_val did not improve from 0.26763
# Epoch 11/5000
#  - 40s - loss: 0.1526 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.64784 - roc_auc_val: 0.63389 - norm_gini: 0.29567 - norm_gini_val: 0.26778
#
# Epoch 00011: norm_gini_val improved from 0.26763 to 0.26778, saving model to keras-5fold-run-01-v1-fold-01-run-01.check
# Epoch 12/5000
#  - 39s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64875 - roc_auc_val: 0.63381 - norm_gini: 0.2975 - norm_gini_val: 0.26762
#
# Epoch 00012: norm_gini_val did not improve from 0.26778
# Epoch 13/5000
#  - 39s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.64843 - roc_auc_val: 0.63467 - norm_gini: 0.29687 - norm_gini_val: 0.26935
#
# Epoch 00013: norm_gini_val improved from 0.26778 to 0.26935, saving model to keras-5fold-run-01-v1-fold-01-run-01.check
# Epoch 14/5000
#  - 39s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65175 - roc_auc_val: 0.63422 - norm_gini: 0.30351 - norm_gini_val: 0.26843
#
# Epoch 00014: norm_gini_val did not improve from 0.26935
# Epoch 15/5000
#  - 39s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65222 - roc_auc_val: 0.63396 - norm_gini: 0.30444 - norm_gini_val: 0.26793
#
# Epoch 00015: norm_gini_val did not improve from 0.26935
# Epoch 16/5000
#  - 39s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65322 - roc_auc_val: 0.63414 - norm_gini: 0.30645 - norm_gini_val: 0.26829
#
# Epoch 00016: norm_gini_val did not improve from 0.26935
# Epoch 17/5000
#  - 39s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1522 - val_acc: 0.9635
# roc_auc: 0.65446 - roc_auc_val: 0.63405 - norm_gini: 0.30892 - norm_gini_val: 0.26809
#
# Epoch 00017: norm_gini_val did not improve from 0.26935
# Epoch 18/5000
#  - 39s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65423 - roc_auc_val: 0.63596 - norm_gini: 0.30845 - norm_gini_val: 0.27192
#
# Epoch 00018: norm_gini_val improved from 0.26935 to 0.27192, saving model to keras-5fold-run-01-v1-fold-01-run-01.check
# Epoch 19/5000
#  - 39s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65471 - roc_auc_val: 0.63489 - norm_gini: 0.30942 - norm_gini_val: 0.26979
#
# Epoch 00019: norm_gini_val did not improve from 0.27192
# Epoch 20/5000
#  - 39s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.6572 - roc_auc_val: 0.63415 - norm_gini: 0.31439 - norm_gini_val: 0.26831
#
# Epoch 00020: norm_gini_val did not improve from 0.27192
# Epoch 21/5000
#  - 40s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65684 - roc_auc_val: 0.63511 - norm_gini: 0.31368 - norm_gini_val: 0.27023
#
# Epoch 00021: norm_gini_val did not improve from 0.27192
# Epoch 22/5000
#  - 41s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65752 - roc_auc_val: 0.63489 - norm_gini: 0.31504 - norm_gini_val: 0.26979
#
# Epoch 00022: norm_gini_val did not improve from 0.27192
# Epoch 23/5000
#  - 41s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65646 - roc_auc_val: 0.63321 - norm_gini: 0.31292 - norm_gini_val: 0.26641
#
# Epoch 00023: norm_gini_val did not improve from 0.27192
# Epoch 24/5000
#  - 39s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65777 - roc_auc_val: 0.63414 - norm_gini: 0.31555 - norm_gini_val: 0.26827
#
# Epoch 00024: norm_gini_val did not improve from 0.27192
# Epoch 25/5000
#  - 42s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.6592 - roc_auc_val: 0.63172 - norm_gini: 0.3184 - norm_gini_val: 0.26344
#
# Epoch 00025: norm_gini_val did not improve from 0.27192
# Epoch 26/5000
#  - 40s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65846 - roc_auc_val: 0.63481 - norm_gini: 0.31692 - norm_gini_val: 0.26962
#
# Epoch 00026: norm_gini_val did not improve from 0.27192
# Epoch 27/5000
#  - 39s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65914 - roc_auc_val: 0.63409 - norm_gini: 0.31827 - norm_gini_val: 0.26818
#
# Epoch 00027: norm_gini_val did not improve from 0.27192
# Epoch 28/5000
#  - 40s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9636
# roc_auc: 0.65999 - roc_auc_val: 0.63496 - norm_gini: 0.31998 - norm_gini_val: 0.26993
#
# Epoch 00028: norm_gini_val did not improve from 0.27192
# Epoch 00028: early stopping
#
#  Fold 1 Run 1 Log-loss: 0.15228
#  Fold 1 Run 1 AUC: 0.63596
#  Fold 1 Run 1 normalized gini: 0.27192
#
#  Fold 1 - Run 2
#
# Train on 446408 samples, validate on 148804 samples
# Epoch 1/5000
#  - 46s - loss: 0.1842 - acc: 0.9531 - val_loss: 0.1533 - val_acc: 0.9635
# roc_auc: 0.62687 - roc_auc_val: 0.61997 - norm_gini: 0.25373 - norm_gini_val: 0.23994
#
# Epoch 00001: norm_gini_val improved from -inf to 0.23994, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 2/5000
#  - 46s - loss: 0.1553 - acc: 0.9635 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.63005 - roc_auc_val: 0.62861 - norm_gini: 0.2601 - norm_gini_val: 0.25723
#
# Epoch 00002: norm_gini_val improved from 0.23994 to 0.25723, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 3/5000
#  - 45s - loss: 0.1540 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.63575 - roc_auc_val: 0.62878 - norm_gini: 0.2715 - norm_gini_val: 0.25757
#
# Epoch 00003: norm_gini_val improved from 0.25723 to 0.25757, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 4/5000
#  - 44s - loss: 0.1537 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.63735 - roc_auc_val: 0.62901 - norm_gini: 0.27469 - norm_gini_val: 0.25802
#
# Epoch 00004: norm_gini_val improved from 0.25757 to 0.25802, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 5/5000
#  - 45s - loss: 0.1533 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.64078 - roc_auc_val: 0.63163 - norm_gini: 0.28156 - norm_gini_val: 0.26327
#
# Epoch 00005: norm_gini_val improved from 0.25802 to 0.26327, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 6/5000
#  - 45s - loss: 0.1532 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64179 - roc_auc_val: 0.63333 - norm_gini: 0.28359 - norm_gini_val: 0.26666
#
# Epoch 00006: norm_gini_val improved from 0.26327 to 0.26666, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 7/5000
#  - 46s - loss: 0.1528 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.64394 - roc_auc_val: 0.63373 - norm_gini: 0.28788 - norm_gini_val: 0.26746
#
# Epoch 00007: norm_gini_val improved from 0.26666 to 0.26746, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 8/5000
#  - 45s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.64477 - roc_auc_val: 0.63494 - norm_gini: 0.28953 - norm_gini_val: 0.26988
#
# Epoch 00008: norm_gini_val improved from 0.26746 to 0.26988, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 9/5000
#  - 44s - loss: 0.1527 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.6468 - roc_auc_val: 0.63452 - norm_gini: 0.29361 - norm_gini_val: 0.26905
#
# Epoch 00009: norm_gini_val did not improve from 0.26988
# Epoch 10/5000
#  - 46s - loss: 0.1527 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.64753 - roc_auc_val: 0.63273 - norm_gini: 0.29507 - norm_gini_val: 0.26546
#
# Epoch 00010: norm_gini_val did not improve from 0.26988
# Epoch 11/5000
#  - 45s - loss: 0.1525 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.64954 - roc_auc_val: 0.63479 - norm_gini: 0.29908 - norm_gini_val: 0.26957
#
# Epoch 00011: norm_gini_val did not improve from 0.26988
# Epoch 12/5000
#  - 45s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64828 - roc_auc_val: 0.63083 - norm_gini: 0.29656 - norm_gini_val: 0.26167
#
# Epoch 00012: norm_gini_val did not improve from 0.26988
# Epoch 13/5000
#  - 45s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65031 - roc_auc_val: 0.63412 - norm_gini: 0.30062 - norm_gini_val: 0.26824
#
# Epoch 00013: norm_gini_val did not improve from 0.26988
# Epoch 14/5000
#  - 45s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1522 - val_acc: 0.9635
# roc_auc: 0.65208 - roc_auc_val: 0.63509 - norm_gini: 0.30416 - norm_gini_val: 0.27017
#
# Epoch 00014: norm_gini_val improved from 0.26988 to 0.27017, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 15/5000
#  - 45s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1522 - val_acc: 0.9635
# roc_auc: 0.65336 - roc_auc_val: 0.63489 - norm_gini: 0.30672 - norm_gini_val: 0.26979
#
# Epoch 00015: norm_gini_val did not improve from 0.27017
# Epoch 16/5000
#  - 45s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65249 - roc_auc_val: 0.63431 - norm_gini: 0.30498 - norm_gini_val: 0.26861
#
# Epoch 00016: norm_gini_val did not improve from 0.27017
# Epoch 17/5000
#  - 45s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65475 - roc_auc_val: 0.63585 - norm_gini: 0.30949 - norm_gini_val: 0.27169
#
# Epoch 00017: norm_gini_val improved from 0.27017 to 0.27169, saving model to keras-5fold-run-01-v1-fold-01-run-02.check
# Epoch 18/5000
#  - 45s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1522 - val_acc: 0.9635
# roc_auc: 0.65545 - roc_auc_val: 0.63553 - norm_gini: 0.31089 - norm_gini_val: 0.27106
#
# Epoch 00018: norm_gini_val did not improve from 0.27169
# Epoch 19/5000
#  - 45s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65645 - roc_auc_val: 0.63394 - norm_gini: 0.31289 - norm_gini_val: 0.26788
#
# Epoch 00019: norm_gini_val did not improve from 0.27169
# Epoch 20/5000
#  - 45s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65713 - roc_auc_val: 0.63286 - norm_gini: 0.31426 - norm_gini_val: 0.26572
#
# Epoch 00020: norm_gini_val did not improve from 0.27169
# Epoch 21/5000
#  - 45s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65776 - roc_auc_val: 0.63338 - norm_gini: 0.31551 - norm_gini_val: 0.26675
#
# Epoch 00021: norm_gini_val did not improve from 0.27169
# Epoch 22/5000
#  - 45s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65785 - roc_auc_val: 0.63292 - norm_gini: 0.31569 - norm_gini_val: 0.26584
#
# Epoch 00022: norm_gini_val did not improve from 0.27169
# Epoch 23/5000
#  - 44s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65907 - roc_auc_val: 0.63482 - norm_gini: 0.31814 - norm_gini_val: 0.26964
#
# Epoch 00023: norm_gini_val did not improve from 0.27169
# Epoch 24/5000
#  - 44s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1529 - val_acc: 0.9635
# roc_auc: 0.65901 - roc_auc_val: 0.63238 - norm_gini: 0.31802 - norm_gini_val: 0.26475
#
# Epoch 00024: norm_gini_val did not improve from 0.27169
# Epoch 25/5000
#  - 44s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.6598 - roc_auc_val: 0.63158 - norm_gini: 0.31959 - norm_gini_val: 0.26315
#
# Epoch 00025: norm_gini_val did not improve from 0.27169
# Epoch 26/5000
#  - 44s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.66113 - roc_auc_val: 0.63289 - norm_gini: 0.32226 - norm_gini_val: 0.26577
#
# Epoch 00026: norm_gini_val did not improve from 0.27169
# Epoch 27/5000
#  - 44s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.66047 - roc_auc_val: 0.63427 - norm_gini: 0.32095 - norm_gini_val: 0.26854
#
# Epoch 00027: norm_gini_val did not improve from 0.27169
# Epoch 00027: early stopping
#
#  Fold 1 Run 2 Log-loss: 0.15241
#  Fold 1 Run 2 AUC: 0.63585
#  Fold 1 Run 2 normalized gini: 0.27169
#
#  Fold 1 Log-loss: 0.15207
#  Fold 1 AUC: 0.63717
#  Fold 1 normalized gini: 0.27433
#
#  Time taken: 1 hours 9 minutes and 52.92 seconds.
#
#  Fold 2 - Run 1
#
# Train on 446408 samples, validate on 148804 samples
# Epoch 1/5000
#  - 51s - loss: 0.1840 - acc: 0.9528 - val_loss: 0.1531 - val_acc: 0.9635
# roc_auc: 0.62734 - roc_auc_val: 0.62125 - norm_gini: 0.25468 - norm_gini_val: 0.24249
#
# Epoch 00001: norm_gini_val improved from -inf to 0.24249, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 2/5000
#  - 49s - loss: 0.1549 - acc: 0.9636 - val_loss: 0.1529 - val_acc: 0.9635
# roc_auc: 0.63411 - roc_auc_val: 0.62425 - norm_gini: 0.26821 - norm_gini_val: 0.24851
#
# Epoch 00002: norm_gini_val improved from 0.24249 to 0.24851, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 3/5000
#  - 49s - loss: 0.1539 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.63671 - roc_auc_val: 0.62772 - norm_gini: 0.27341 - norm_gini_val: 0.25545
#
# Epoch 00003: norm_gini_val improved from 0.24851 to 0.25545, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 4/5000
#  - 49s - loss: 0.1535 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64 - roc_auc_val: 0.62947 - norm_gini: 0.28 - norm_gini_val: 0.25893
#
# Epoch 00004: norm_gini_val improved from 0.25545 to 0.25893, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 5/5000
#  - 49s - loss: 0.1532 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.64124 - roc_auc_val: 0.62947 - norm_gini: 0.28249 - norm_gini_val: 0.25894
#
# Epoch 00005: norm_gini_val improved from 0.25893 to 0.25894, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 6/5000
#  - 49s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64469 - roc_auc_val: 0.63018 - norm_gini: 0.28939 - norm_gini_val: 0.26036
#
# Epoch 00006: norm_gini_val improved from 0.25894 to 0.26036, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 7/5000
#  - 48s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64551 - roc_auc_val: 0.63121 - norm_gini: 0.29102 - norm_gini_val: 0.26243
#
# Epoch 00007: norm_gini_val improved from 0.26036 to 0.26243, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 8/5000
#  - 49s - loss: 0.1528 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64751 - roc_auc_val: 0.63138 - norm_gini: 0.29502 - norm_gini_val: 0.26277
#
# Epoch 00008: norm_gini_val improved from 0.26243 to 0.26277, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 9/5000
#  - 49s - loss: 0.1527 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.64888 - roc_auc_val: 0.62832 - norm_gini: 0.29775 - norm_gini_val: 0.25663
#
# Epoch 00009: norm_gini_val did not improve from 0.26277
# Epoch 10/5000
#  - 49s - loss: 0.1525 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65086 - roc_auc_val: 0.63102 - norm_gini: 0.30173 - norm_gini_val: 0.26204
#
# Epoch 00010: norm_gini_val did not improve from 0.26277
# Epoch 11/5000
#  - 48s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65153 - roc_auc_val: 0.63167 - norm_gini: 0.30307 - norm_gini_val: 0.26335
#
# Epoch 00011: norm_gini_val improved from 0.26277 to 0.26335, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 12/5000
#  - 50s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65195 - roc_auc_val: 0.62916 - norm_gini: 0.3039 - norm_gini_val: 0.25832
#
# Epoch 00012: norm_gini_val did not improve from 0.26335
# Epoch 13/5000
#  - 50s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65169 - roc_auc_val: 0.63234 - norm_gini: 0.30338 - norm_gini_val: 0.26468
#
# Epoch 00013: norm_gini_val improved from 0.26335 to 0.26468, saving model to keras-5fold-run-01-v1-fold-02-run-01.check
# Epoch 14/5000
#  - 49s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.6533 - roc_auc_val: 0.63182 - norm_gini: 0.30659 - norm_gini_val: 0.26363
#
# Epoch 00014: norm_gini_val did not improve from 0.26468
# Epoch 15/5000
#  - 50s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65451 - roc_auc_val: 0.63071 - norm_gini: 0.30903 - norm_gini_val: 0.26142
#
# Epoch 00015: norm_gini_val did not improve from 0.26468
# Epoch 16/5000
#  - 51s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9635
# roc_auc: 0.65427 - roc_auc_val: 0.63212 - norm_gini: 0.30854 - norm_gini_val: 0.26424
#
# Epoch 00016: norm_gini_val did not improve from 0.26468
# Epoch 17/5000
#  - 50s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65535 - roc_auc_val: 0.6318 - norm_gini: 0.31071 - norm_gini_val: 0.26359
#
# Epoch 00017: norm_gini_val did not improve from 0.26468
# Epoch 18/5000
#  - 48s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65682 - roc_auc_val: 0.62983 - norm_gini: 0.31364 - norm_gini_val: 0.25965
#
# Epoch 00018: norm_gini_val did not improve from 0.26468
# Epoch 19/5000
#  - 54s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65636 - roc_auc_val: 0.63037 - norm_gini: 0.31272 - norm_gini_val: 0.26075
#
# Epoch 00019: norm_gini_val did not improve from 0.26468
# Epoch 20/5000
#  - 51s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.65723 - roc_auc_val: 0.62907 - norm_gini: 0.31446 - norm_gini_val: 0.25813
#
# Epoch 00020: norm_gini_val did not improve from 0.26468
# Epoch 21/5000
#  - 51s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.6577 - roc_auc_val: 0.62868 - norm_gini: 0.3154 - norm_gini_val: 0.25736
#
# Epoch 00021: norm_gini_val did not improve from 0.26468
# Epoch 22/5000
#  - 51s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.65799 - roc_auc_val: 0.62984 - norm_gini: 0.31599 - norm_gini_val: 0.25967
#
# Epoch 00022: norm_gini_val did not improve from 0.26468
# Epoch 23/5000
#  - 52s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65839 - roc_auc_val: 0.6302 - norm_gini: 0.31678 - norm_gini_val: 0.2604
#
# Epoch 00023: norm_gini_val did not improve from 0.26468
# Epoch 00023: early stopping
#
#  Fold 2 Run 1 Log-loss: 0.15236
#  Fold 2 Run 1 AUC: 0.63234
#  Fold 2 Run 1 normalized gini: 0.26468
#
#  Fold 2 - Run 2
#
# Train on 446408 samples, validate on 148804 samples
# Epoch 1/5000
#  - 59s - loss: 0.1831 - acc: 0.9527 - val_loss: 0.1535 - val_acc: 0.9635
# roc_auc: 0.6265 - roc_auc_val: 0.62221 - norm_gini: 0.253 - norm_gini_val: 0.24442
#
# Epoch 00001: norm_gini_val improved from -inf to 0.24442, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 2/5000
#  - 58s - loss: 0.1551 - acc: 0.9635 - val_loss: 0.1531 - val_acc: 0.9635
# roc_auc: 0.63394 - roc_auc_val: 0.62737 - norm_gini: 0.26788 - norm_gini_val: 0.25475
#
# Epoch 00002: norm_gini_val improved from 0.24442 to 0.25475, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 3/5000
#  - 56s - loss: 0.1541 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.63598 - roc_auc_val: 0.62773 - norm_gini: 0.27196 - norm_gini_val: 0.25547
#
# Epoch 00003: norm_gini_val improved from 0.25475 to 0.25547, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 4/5000
#  - 55s - loss: 0.1537 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.64019 - roc_auc_val: 0.62833 - norm_gini: 0.28038 - norm_gini_val: 0.25667
#
# Epoch 00004: norm_gini_val improved from 0.25547 to 0.25667, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 5/5000
#  - 54s - loss: 0.1533 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9635
# roc_auc: 0.64203 - roc_auc_val: 0.62915 - norm_gini: 0.28407 - norm_gini_val: 0.25829
#
# Epoch 00005: norm_gini_val improved from 0.25667 to 0.25829, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 6/5000
#  - 55s - loss: 0.1531 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.6441 - roc_auc_val: 0.62777 - norm_gini: 0.28819 - norm_gini_val: 0.25553
#
# Epoch 00006: norm_gini_val did not improve from 0.25829
# Epoch 7/5000
#  - 54s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.64444 - roc_auc_val: 0.62796 - norm_gini: 0.28889 - norm_gini_val: 0.25591
#
# Epoch 00007: norm_gini_val did not improve from 0.25829
# Epoch 8/5000
#  - 54s - loss: 0.1528 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64613 - roc_auc_val: 0.63019 - norm_gini: 0.29225 - norm_gini_val: 0.26039
#
# Epoch 00008: norm_gini_val improved from 0.25829 to 0.26039, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 9/5000
#  - 54s - loss: 0.1527 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.6467 - roc_auc_val: 0.62978 - norm_gini: 0.29339 - norm_gini_val: 0.25955
#
# Epoch 00009: norm_gini_val did not improve from 0.26039
# Epoch 10/5000
#  - 54s - loss: 0.1525 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64927 - roc_auc_val: 0.62933 - norm_gini: 0.29853 - norm_gini_val: 0.25867
#
# Epoch 00010: norm_gini_val did not improve from 0.26039
# Epoch 11/5000
#  - 53s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.64955 - roc_auc_val: 0.63001 - norm_gini: 0.29909 - norm_gini_val: 0.26001
#
# Epoch 00011: norm_gini_val did not improve from 0.26039
# Epoch 12/5000
#  - 54s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.6497 - roc_auc_val: 0.63029 - norm_gini: 0.2994 - norm_gini_val: 0.26059
#
# Epoch 00012: norm_gini_val improved from 0.26039 to 0.26059, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 13/5000
#  - 54s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.65237 - roc_auc_val: 0.63042 - norm_gini: 0.30474 - norm_gini_val: 0.26084
#
# Epoch 00013: norm_gini_val improved from 0.26059 to 0.26084, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 14/5000
#  - 54s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65325 - roc_auc_val: 0.62965 - norm_gini: 0.30651 - norm_gini_val: 0.25931
#
# Epoch 00014: norm_gini_val did not improve from 0.26084
# Epoch 15/5000
#  - 54s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9635
# roc_auc: 0.65415 - roc_auc_val: 0.63092 - norm_gini: 0.30831 - norm_gini_val: 0.26183
#
# Epoch 00015: norm_gini_val improved from 0.26084 to 0.26183, saving model to keras-5fold-run-01-v1-fold-02-run-02.check
# Epoch 16/5000
#  - 54s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65593 - roc_auc_val: 0.63051 - norm_gini: 0.31186 - norm_gini_val: 0.26102
#
# Epoch 00016: norm_gini_val did not improve from 0.26183
# Epoch 17/5000
#  - 53s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65688 - roc_auc_val: 0.62784 - norm_gini: 0.31376 - norm_gini_val: 0.25568
#
# Epoch 00017: norm_gini_val did not improve from 0.26183
# Epoch 18/5000
#  - 51s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.65678 - roc_auc_val: 0.62907 - norm_gini: 0.31357 - norm_gini_val: 0.25815
#
# Epoch 00018: norm_gini_val did not improve from 0.26183
# Epoch 19/5000
#  - 53s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.65717 - roc_auc_val: 0.62916 - norm_gini: 0.31434 - norm_gini_val: 0.25832
#
# Epoch 00019: norm_gini_val did not improve from 0.26183
# Epoch 20/5000
#  - 53s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.6578 - roc_auc_val: 0.63009 - norm_gini: 0.31561 - norm_gini_val: 0.26018
#
# Epoch 00020: norm_gini_val did not improve from 0.26183
# Epoch 21/5000
#  - 53s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65847 - roc_auc_val: 0.62857 - norm_gini: 0.31694 - norm_gini_val: 0.25714
#
# Epoch 00021: norm_gini_val did not improve from 0.26183
# Epoch 22/5000
#  - 53s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65903 - roc_auc_val: 0.62771 - norm_gini: 0.31806 - norm_gini_val: 0.25542
#
# Epoch 00022: norm_gini_val did not improve from 0.26183
# Epoch 23/5000
#  - 53s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9635
# roc_auc: 0.65948 - roc_auc_val: 0.62601 - norm_gini: 0.31895 - norm_gini_val: 0.25202
#
# Epoch 00023: norm_gini_val did not improve from 0.26183
# Epoch 24/5000
#  - 53s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65916 - roc_auc_val: 0.62864 - norm_gini: 0.31832 - norm_gini_val: 0.25728
#
# Epoch 00024: norm_gini_val did not improve from 0.26183
# Epoch 25/5000
#  - 51s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.66085 - roc_auc_val: 0.62919 - norm_gini: 0.32171 - norm_gini_val: 0.25837
#
# Epoch 00025: norm_gini_val did not improve from 0.26183
# Epoch 00025: early stopping
#
#  Fold 2 Run 2 Log-loss: 0.15245
#  Fold 2 Run 2 AUC: 0.63092
#  Fold 2 Run 2 normalized gini: 0.26183
#
#  Fold 2 Log-loss: 0.15230
#  Fold 2 AUC: 0.63303
#  Fold 2 normalized gini: 0.26606
#
#  Time taken: 1 hours 13 minutes and 21.79 seconds.
#
#  Fold 3 - Run 1
#
# Train on 446410 samples, validate on 148802 samples
# Epoch 1/5000
#  - 64s - loss: 0.1845 - acc: 0.9517 - val_loss: 0.1533 - val_acc: 0.9636
# roc_auc: 0.62715 - roc_auc_val: 0.61716 - norm_gini: 0.2543 - norm_gini_val: 0.23433
#
# Epoch 00001: norm_gini_val improved from -inf to 0.23433, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 2/5000
#  - 60s - loss: 0.1550 - acc: 0.9636 - val_loss: 0.1529 - val_acc: 0.9636
# roc_auc: 0.63278 - roc_auc_val: 0.62403 - norm_gini: 0.26556 - norm_gini_val: 0.24806
#
# Epoch 00002: norm_gini_val improved from 0.23433 to 0.24806, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 3/5000
#  - 60s - loss: 0.1540 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.63674 - roc_auc_val: 0.628 - norm_gini: 0.27348 - norm_gini_val: 0.256
#
# Epoch 00003: norm_gini_val improved from 0.24806 to 0.25600, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 4/5000
#  - 60s - loss: 0.1535 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9636
# roc_auc: 0.63821 - roc_auc_val: 0.62894 - norm_gini: 0.27643 - norm_gini_val: 0.25787
#
# Epoch 00004: norm_gini_val improved from 0.25600 to 0.25787, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 5/5000
#  - 60s - loss: 0.1534 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.64121 - roc_auc_val: 0.63082 - norm_gini: 0.28242 - norm_gini_val: 0.26164
#
# Epoch 00005: norm_gini_val improved from 0.25787 to 0.26164, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 6/5000
#  - 60s - loss: 0.1530 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.64249 - roc_auc_val: 0.63134 - norm_gini: 0.28498 - norm_gini_val: 0.26268
#
# Epoch 00006: norm_gini_val improved from 0.26164 to 0.26268, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 7/5000
#  - 60s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.64531 - roc_auc_val: 0.63141 - norm_gini: 0.29062 - norm_gini_val: 0.26281
#
# Epoch 00007: norm_gini_val improved from 0.26268 to 0.26281, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 8/5000
#  - 60s - loss: 0.1528 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.64471 - roc_auc_val: 0.63176 - norm_gini: 0.28942 - norm_gini_val: 0.26352
#
# Epoch 00008: norm_gini_val improved from 0.26281 to 0.26352, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 9/5000
#  - 59s - loss: 0.1527 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.64766 - roc_auc_val: 0.6315 - norm_gini: 0.29533 - norm_gini_val: 0.263
#
# Epoch 00009: norm_gini_val did not improve from 0.26352
# Epoch 10/5000
#  - 60s - loss: 0.1526 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.64946 - roc_auc_val: 0.63304 - norm_gini: 0.29891 - norm_gini_val: 0.26608
#
# Epoch 00010: norm_gini_val improved from 0.26352 to 0.26608, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 11/5000
#  - 60s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65093 - roc_auc_val: 0.63267 - norm_gini: 0.30187 - norm_gini_val: 0.26534
#
# Epoch 00011: norm_gini_val did not improve from 0.26608
# Epoch 12/5000
#  - 58s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65137 - roc_auc_val: 0.63237 - norm_gini: 0.30275 - norm_gini_val: 0.26475
#
# Epoch 00012: norm_gini_val did not improve from 0.26608
# Epoch 13/5000
#  - 60s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65194 - roc_auc_val: 0.63373 - norm_gini: 0.30388 - norm_gini_val: 0.26746
#
# Epoch 00013: norm_gini_val improved from 0.26608 to 0.26746, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 14/5000
#  - 60s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65196 - roc_auc_val: 0.63288 - norm_gini: 0.30392 - norm_gini_val: 0.26575
#
# Epoch 00014: norm_gini_val did not improve from 0.26746
# Epoch 15/5000
#  - 58s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65284 - roc_auc_val: 0.63343 - norm_gini: 0.30568 - norm_gini_val: 0.26686
#
# Epoch 00015: norm_gini_val did not improve from 0.26746
# Epoch 16/5000
#  - 60s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65432 - roc_auc_val: 0.63351 - norm_gini: 0.30865 - norm_gini_val: 0.26703
#
# Epoch 00016: norm_gini_val did not improve from 0.26746
# Epoch 17/5000
#  - 60s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.654 - roc_auc_val: 0.63452 - norm_gini: 0.30801 - norm_gini_val: 0.26903
#
# Epoch 00017: norm_gini_val improved from 0.26746 to 0.26903, saving model to keras-5fold-run-01-v1-fold-03-run-01.check
# Epoch 18/5000
#  - 59s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9636
# roc_auc: 0.65534 - roc_auc_val: 0.63398 - norm_gini: 0.31068 - norm_gini_val: 0.26795
#
# Epoch 00018: norm_gini_val did not improve from 0.26903
# Epoch 19/5000
#  - 60s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65659 - roc_auc_val: 0.634 - norm_gini: 0.31319 - norm_gini_val: 0.268
#
# Epoch 00019: norm_gini_val did not improve from 0.26903
# Epoch 20/5000
#  - 60s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65642 - roc_auc_val: 0.63335 - norm_gini: 0.31284 - norm_gini_val: 0.2667
#
# Epoch 00020: norm_gini_val did not improve from 0.26903
# Epoch 21/5000
#  - 60s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65707 - roc_auc_val: 0.6335 - norm_gini: 0.31414 - norm_gini_val: 0.267
#
# Epoch 00021: norm_gini_val did not improve from 0.26903
# Epoch 22/5000
#  - 60s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65763 - roc_auc_val: 0.63374 - norm_gini: 0.31527 - norm_gini_val: 0.26749
#
# Epoch 00022: norm_gini_val did not improve from 0.26903
# Epoch 23/5000
#  - 60s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65783 - roc_auc_val: 0.63351 - norm_gini: 0.31566 - norm_gini_val: 0.26701
#
# Epoch 00023: norm_gini_val did not improve from 0.26903
# Epoch 24/5000
#  - 60s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65834 - roc_auc_val: 0.63422 - norm_gini: 0.31668 - norm_gini_val: 0.26843
#
# Epoch 00024: norm_gini_val did not improve from 0.26903
# Epoch 25/5000
#  - 59s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65901 - roc_auc_val: 0.6336 - norm_gini: 0.31803 - norm_gini_val: 0.26719
#
# Epoch 00025: norm_gini_val did not improve from 0.26903
# Epoch 26/5000
#  - 60s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65852 - roc_auc_val: 0.63325 - norm_gini: 0.31705 - norm_gini_val: 0.2665
#
# Epoch 00026: norm_gini_val did not improve from 0.26903
# Epoch 27/5000
#  - 60s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65919 - roc_auc_val: 0.63263 - norm_gini: 0.31838 - norm_gini_val: 0.26526
#
# Epoch 00027: norm_gini_val did not improve from 0.26903
# Epoch 00027: early stopping
#
#  Fold 3 Run 1 Log-loss: 0.15257
#  Fold 3 Run 1 AUC: 0.63452
#  Fold 3 Run 1 normalized gini: 0.26903
#
#  Fold 3 - Run 2
#
# Train on 446410 samples, validate on 148802 samples
# Epoch 1/5000
#  - 71s - loss: 0.1848 - acc: 0.9519 - val_loss: 0.1531 - val_acc: 0.9636
# roc_auc: 0.62714 - roc_auc_val: 0.62094 - norm_gini: 0.25429 - norm_gini_val: 0.24188
#
# Epoch 00001: norm_gini_val improved from -inf to 0.24188, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 2/5000
#  - 65s - loss: 0.1555 - acc: 0.9635 - val_loss: 0.1534 - val_acc: 0.9636
# roc_auc: 0.63149 - roc_auc_val: 0.62694 - norm_gini: 0.26298 - norm_gini_val: 0.25389
#
# Epoch 00002: norm_gini_val improved from 0.24188 to 0.25389, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 3/5000
#  - 64s - loss: 0.1541 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.63722 - roc_auc_val: 0.62997 - norm_gini: 0.27445 - norm_gini_val: 0.25993
#
# Epoch 00003: norm_gini_val improved from 0.25389 to 0.25993, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 4/5000
#  - 65s - loss: 0.1536 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9636
# roc_auc: 0.6374 - roc_auc_val: 0.62787 - norm_gini: 0.27479 - norm_gini_val: 0.25575
#
# Epoch 00004: norm_gini_val did not improve from 0.25993
# Epoch 5/5000
#  - 66s - loss: 0.1532 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.63955 - roc_auc_val: 0.63077 - norm_gini: 0.2791 - norm_gini_val: 0.26154
#
# Epoch 00005: norm_gini_val improved from 0.25993 to 0.26154, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 6/5000
#  - 64s - loss: 0.1530 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.6428 - roc_auc_val: 0.63252 - norm_gini: 0.2856 - norm_gini_val: 0.26504
#
# Epoch 00006: norm_gini_val improved from 0.26154 to 0.26504, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 7/5000
#  - 65s - loss: 0.1528 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.64402 - roc_auc_val: 0.63169 - norm_gini: 0.28803 - norm_gini_val: 0.26337
#
# Epoch 00007: norm_gini_val did not improve from 0.26504
# Epoch 8/5000
#  - 65s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.64527 - roc_auc_val: 0.63277 - norm_gini: 0.29055 - norm_gini_val: 0.26554
#
# Epoch 00008: norm_gini_val improved from 0.26504 to 0.26554, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 9/5000
#  - 64s - loss: 0.1527 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9636
# roc_auc: 0.64646 - roc_auc_val: 0.63228 - norm_gini: 0.29292 - norm_gini_val: 0.26456
#
# Epoch 00009: norm_gini_val did not improve from 0.26554
# Epoch 10/5000
#  - 65s - loss: 0.1526 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.64754 - roc_auc_val: 0.63297 - norm_gini: 0.29508 - norm_gini_val: 0.26594
#
# Epoch 00010: norm_gini_val improved from 0.26554 to 0.26594, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 11/5000
#  - 65s - loss: 0.1525 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.64889 - roc_auc_val: 0.63241 - norm_gini: 0.29779 - norm_gini_val: 0.26483
#
# Epoch 00011: norm_gini_val did not improve from 0.26594
# Epoch 12/5000
#  - 64s - loss: 0.1525 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65043 - roc_auc_val: 0.63365 - norm_gini: 0.30086 - norm_gini_val: 0.2673
#
# Epoch 00012: norm_gini_val improved from 0.26594 to 0.26730, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 13/5000
#  - 65s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9636
# roc_auc: 0.65224 - roc_auc_val: 0.63401 - norm_gini: 0.30448 - norm_gini_val: 0.26803
#
# Epoch 00013: norm_gini_val improved from 0.26730 to 0.26803, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 14/5000
#  - 65s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65321 - roc_auc_val: 0.63267 - norm_gini: 0.30642 - norm_gini_val: 0.26534
#
# Epoch 00014: norm_gini_val did not improve from 0.26803
# Epoch 15/5000
#  - 64s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9636
# roc_auc: 0.65442 - roc_auc_val: 0.63399 - norm_gini: 0.30885 - norm_gini_val: 0.26797
#
# Epoch 00015: norm_gini_val did not improve from 0.26803
# Epoch 16/5000
#  - 65s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65335 - roc_auc_val: 0.63436 - norm_gini: 0.30669 - norm_gini_val: 0.26872
#
# Epoch 00016: norm_gini_val improved from 0.26803 to 0.26872, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 17/5000
#  - 65s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9636
# roc_auc: 0.65616 - roc_auc_val: 0.63445 - norm_gini: 0.31232 - norm_gini_val: 0.26891
#
# Epoch 00017: norm_gini_val improved from 0.26872 to 0.26891, saving model to keras-5fold-run-01-v1-fold-03-run-02.check
# Epoch 18/5000
#  - 64s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1529 - val_acc: 0.9636
# roc_auc: 0.65633 - roc_auc_val: 0.63297 - norm_gini: 0.31266 - norm_gini_val: 0.26594
#
# Epoch 00018: norm_gini_val did not improve from 0.26891
# Epoch 19/5000
#  - 65s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.6584 - roc_auc_val: 0.6335 - norm_gini: 0.31679 - norm_gini_val: 0.26701
#
# Epoch 00019: norm_gini_val did not improve from 0.26891
# Epoch 20/5000
#  - 65s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65755 - roc_auc_val: 0.63318 - norm_gini: 0.3151 - norm_gini_val: 0.26637
#
# Epoch 00020: norm_gini_val did not improve from 0.26891
# Epoch 21/5000
#  - 64s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1523 - val_acc: 0.9636
# roc_auc: 0.65995 - roc_auc_val: 0.63333 - norm_gini: 0.31991 - norm_gini_val: 0.26667
#
# Epoch 00021: norm_gini_val did not improve from 0.26891
# Epoch 22/5000
#  - 65s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.66109 - roc_auc_val: 0.63113 - norm_gini: 0.32218 - norm_gini_val: 0.26227
#
# Epoch 00022: norm_gini_val did not improve from 0.26891
# Epoch 23/5000
#  - 65s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.66013 - roc_auc_val: 0.63298 - norm_gini: 0.32026 - norm_gini_val: 0.26597
#
# Epoch 00023: norm_gini_val did not improve from 0.26891
# Epoch 24/5000
#  - 65s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.66021 - roc_auc_val: 0.63123 - norm_gini: 0.32042 - norm_gini_val: 0.26246
#
# Epoch 00024: norm_gini_val did not improve from 0.26891
# Epoch 25/5000
#  - 65s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.66245 - roc_auc_val: 0.63071 - norm_gini: 0.32491 - norm_gini_val: 0.26142
#
# Epoch 00025: norm_gini_val did not improve from 0.26891
# Epoch 26/5000
#  - 65s - loss: 0.1516 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.66258 - roc_auc_val: 0.63323 - norm_gini: 0.32516 - norm_gini_val: 0.26645
#
# Epoch 00026: norm_gini_val did not improve from 0.26891
# Epoch 27/5000
#  - 65s - loss: 0.1516 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.66317 - roc_auc_val: 0.6313 - norm_gini: 0.32633 - norm_gini_val: 0.2626
#
# Epoch 00027: norm_gini_val did not improve from 0.26891
# Epoch 00027: early stopping
#
#  Fold 3 Run 2 Log-loss: 0.15232
#  Fold 3 Run 2 AUC: 0.63445
#  Fold 3 Run 2 normalized gini: 0.26891
#
#  Fold 3 Log-loss: 0.15221
#  Fold 3 AUC: 0.63581
#  Fold 3 normalized gini: 0.27163
#
#  Time taken: 1 hours 33 minutes and 57.65 seconds.
#
#  Fold 4 - Run 1
#
# Train on 446410 samples, validate on 148802 samples
# Epoch 1/5000
#  - 77s - loss: 0.1842 - acc: 0.9530 - val_loss: 0.1540 - val_acc: 0.9636
# roc_auc: 0.62485 - roc_auc_val: 0.61566 - norm_gini: 0.24969 - norm_gini_val: 0.23132
#
# Epoch 00001: norm_gini_val improved from -inf to 0.23132, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 2/5000
#  - 71s - loss: 0.1550 - acc: 0.9635 - val_loss: 0.1528 - val_acc: 0.9636
# roc_auc: 0.6358 - roc_auc_val: 0.62623 - norm_gini: 0.27161 - norm_gini_val: 0.25246
#
# Epoch 00002: norm_gini_val improved from 0.23132 to 0.25246, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 3/5000
#  - 71s - loss: 0.1538 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9636
# roc_auc: 0.63705 - roc_auc_val: 0.62365 - norm_gini: 0.2741 - norm_gini_val: 0.2473
#
# Epoch 00003: norm_gini_val did not improve from 0.25246
# Epoch 4/5000
#  - 70s - loss: 0.1535 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.63931 - roc_auc_val: 0.62646 - norm_gini: 0.27863 - norm_gini_val: 0.25292
#
# Epoch 00004: norm_gini_val improved from 0.25246 to 0.25292, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 5/5000
#  - 71s - loss: 0.1532 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.64212 - roc_auc_val: 0.62678 - norm_gini: 0.28423 - norm_gini_val: 0.25357
#
# Epoch 00005: norm_gini_val improved from 0.25292 to 0.25357, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 6/5000
#  - 71s - loss: 0.1530 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.6414 - roc_auc_val: 0.62659 - norm_gini: 0.28281 - norm_gini_val: 0.25318
#
# Epoch 00006: norm_gini_val did not improve from 0.25357
# Epoch 7/5000
#  - 70s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.64482 - roc_auc_val: 0.62864 - norm_gini: 0.28964 - norm_gini_val: 0.25727
#
# Epoch 00007: norm_gini_val improved from 0.25357 to 0.25727, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 8/5000
#  - 71s - loss: 0.1528 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.64766 - roc_auc_val: 0.62811 - norm_gini: 0.29532 - norm_gini_val: 0.25622
#
# Epoch 00008: norm_gini_val did not improve from 0.25727
# Epoch 9/5000
#  - 71s - loss: 0.1526 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.64777 - roc_auc_val: 0.62686 - norm_gini: 0.29554 - norm_gini_val: 0.25372
#
# Epoch 00009: norm_gini_val did not improve from 0.25727
# Epoch 10/5000
#  - 70s - loss: 0.1526 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.64888 - roc_auc_val: 0.63074 - norm_gini: 0.29776 - norm_gini_val: 0.26149
#
# Epoch 00010: norm_gini_val improved from 0.25727 to 0.26149, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 11/5000
#  - 71s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.65069 - roc_auc_val: 0.63008 - norm_gini: 0.30139 - norm_gini_val: 0.26016
#
# Epoch 00011: norm_gini_val did not improve from 0.26149
# Epoch 12/5000
#  - 71s - loss: 0.1524 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9635
# roc_auc: 0.65178 - roc_auc_val: 0.62836 - norm_gini: 0.30357 - norm_gini_val: 0.25673
#
# Epoch 00012: norm_gini_val did not improve from 0.26149
# Epoch 13/5000
#  - 71s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65303 - roc_auc_val: 0.6311 - norm_gini: 0.30607 - norm_gini_val: 0.26219
#
# Epoch 00013: norm_gini_val improved from 0.26149 to 0.26219, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 14/5000
#  - 71s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65328 - roc_auc_val: 0.63155 - norm_gini: 0.30656 - norm_gini_val: 0.2631
#
# Epoch 00014: norm_gini_val improved from 0.26219 to 0.26310, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 15/5000
#  - 70s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65485 - roc_auc_val: 0.62984 - norm_gini: 0.3097 - norm_gini_val: 0.25969
#
# Epoch 00015: norm_gini_val did not improve from 0.26310
# Epoch 16/5000
#  - 71s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65531 - roc_auc_val: 0.62976 - norm_gini: 0.31062 - norm_gini_val: 0.25953
#
# Epoch 00016: norm_gini_val did not improve from 0.26310
# Epoch 17/5000
#  - 71s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65681 - roc_auc_val: 0.63063 - norm_gini: 0.31361 - norm_gini_val: 0.26126
#
# Epoch 00017: norm_gini_val did not improve from 0.26310
# Epoch 18/5000
#  - 70s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65652 - roc_auc_val: 0.63092 - norm_gini: 0.31305 - norm_gini_val: 0.26184
#
# Epoch 00018: norm_gini_val did not improve from 0.26310
# Epoch 19/5000
#  - 71s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.6556 - roc_auc_val: 0.63121 - norm_gini: 0.3112 - norm_gini_val: 0.26243
#
# Epoch 00019: norm_gini_val did not improve from 0.26310
# Epoch 20/5000
#  - 71s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65786 - roc_auc_val: 0.63067 - norm_gini: 0.31572 - norm_gini_val: 0.26134
#
# Epoch 00020: norm_gini_val did not improve from 0.26310
# Epoch 21/5000
#  - 70s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65818 - roc_auc_val: 0.6308 - norm_gini: 0.31636 - norm_gini_val: 0.2616
#
# Epoch 00021: norm_gini_val did not improve from 0.26310
# Epoch 22/5000
#  - 71s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.6577 - roc_auc_val: 0.63156 - norm_gini: 0.3154 - norm_gini_val: 0.26313
#
# Epoch 00022: norm_gini_val improved from 0.26310 to 0.26313, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 23/5000
#  - 71s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9635
# roc_auc: 0.65949 - roc_auc_val: 0.63278 - norm_gini: 0.31899 - norm_gini_val: 0.26556
#
# Epoch 00023: norm_gini_val improved from 0.26313 to 0.26556, saving model to keras-5fold-run-01-v1-fold-04-run-01.check
# Epoch 24/5000
#  - 71s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65864 - roc_auc_val: 0.63204 - norm_gini: 0.31728 - norm_gini_val: 0.26409
#
# Epoch 00024: norm_gini_val did not improve from 0.26556
# Epoch 25/5000
#  - 71s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.65927 - roc_auc_val: 0.6313 - norm_gini: 0.31853 - norm_gini_val: 0.2626
#
# Epoch 00025: norm_gini_val did not improve from 0.26556
# Epoch 26/5000
#  - 70s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.66029 - roc_auc_val: 0.6318 - norm_gini: 0.32057 - norm_gini_val: 0.2636
#
# Epoch 00026: norm_gini_val did not improve from 0.26556
# Epoch 27/5000
#  - 71s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.66051 - roc_auc_val: 0.6309 - norm_gini: 0.32102 - norm_gini_val: 0.26179
#
# Epoch 00027: norm_gini_val did not improve from 0.26556
# Epoch 28/5000
#  - 71s - loss: 0.1516 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.66041 - roc_auc_val: 0.6301 - norm_gini: 0.32083 - norm_gini_val: 0.26021
#
# Epoch 00028: norm_gini_val did not improve from 0.26556
# Epoch 29/5000
#  - 70s - loss: 0.1517 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.66124 - roc_auc_val: 0.6298 - norm_gini: 0.32248 - norm_gini_val: 0.25959
#
# Epoch 00029: norm_gini_val did not improve from 0.26556
# Epoch 30/5000
#  - 71s - loss: 0.1516 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.66319 - roc_auc_val: 0.63018 - norm_gini: 0.32638 - norm_gini_val: 0.26035
#
# Epoch 00030: norm_gini_val did not improve from 0.26556
# Epoch 31/5000
#  - 71s - loss: 0.1516 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.6629 - roc_auc_val: 0.63001 - norm_gini: 0.32581 - norm_gini_val: 0.26003
#
# Epoch 00031: norm_gini_val did not improve from 0.26556
# Epoch 32/5000
#  - 70s - loss: 0.1514 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.66395 - roc_auc_val: 0.63063 - norm_gini: 0.3279 - norm_gini_val: 0.26126
#
# Epoch 00032: norm_gini_val did not improve from 0.26556
# Epoch 33/5000
#  - 71s - loss: 0.1516 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.66297 - roc_auc_val: 0.63004 - norm_gini: 0.32594 - norm_gini_val: 0.26007
#
# Epoch 00033: norm_gini_val did not improve from 0.26556
# Epoch 00033: early stopping
#
#  Fold 4 Run 1 Log-loss: 0.15268
#  Fold 4 Run 1 AUC: 0.63278
#  Fold 4 Run 1 normalized gini: 0.26556
#
#  Fold 4 - Run 2
#
# Train on 446410 samples, validate on 148802 samples
# Epoch 1/5000
#  - 84s - loss: 0.1837 - acc: 0.9528 - val_loss: 0.1532 - val_acc: 0.9636
# roc_auc: 0.62571 - roc_auc_val: 0.6209 - norm_gini: 0.25142 - norm_gini_val: 0.24181
#
# Epoch 00001: norm_gini_val improved from -inf to 0.24181, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 2/5000
#  - 78s - loss: 0.1551 - acc: 0.9636 - val_loss: 0.1528 - val_acc: 0.9636
# roc_auc: 0.63518 - roc_auc_val: 0.62693 - norm_gini: 0.27037 - norm_gini_val: 0.25385
#
# Epoch 00002: norm_gini_val improved from 0.24181 to 0.25385, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 3/5000
#  - 78s - loss: 0.1539 - acc: 0.9636 - val_loss: 0.1527 - val_acc: 0.9636
# roc_auc: 0.63759 - roc_auc_val: 0.62719 - norm_gini: 0.27518 - norm_gini_val: 0.25438
#
# Epoch 00003: norm_gini_val improved from 0.25385 to 0.25438, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 4/5000
#  - 79s - loss: 0.1536 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.64021 - roc_auc_val: 0.62933 - norm_gini: 0.28042 - norm_gini_val: 0.25867
#
# Epoch 00004: norm_gini_val improved from 0.25438 to 0.25867, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 5/5000
#  - 78s - loss: 0.1532 - acc: 0.9636 - val_loss: 0.1530 - val_acc: 0.9636
# roc_auc: 0.64228 - roc_auc_val: 0.62727 - norm_gini: 0.28456 - norm_gini_val: 0.25454
#
# Epoch 00005: norm_gini_val did not improve from 0.25867
# Epoch 6/5000
#  - 79s - loss: 0.1531 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.64542 - roc_auc_val: 0.62981 - norm_gini: 0.29085 - norm_gini_val: 0.25963
#
# Epoch 00006: norm_gini_val improved from 0.25867 to 0.25963, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 7/5000
#  - 79s - loss: 0.1529 - acc: 0.9636 - val_loss: 0.1529 - val_acc: 0.9636
# roc_auc: 0.6458 - roc_auc_val: 0.62911 - norm_gini: 0.2916 - norm_gini_val: 0.25821
#
# Epoch 00007: norm_gini_val did not improve from 0.25963
# Epoch 8/5000
#  - 78s - loss: 0.1527 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.64749 - roc_auc_val: 0.62938 - norm_gini: 0.29498 - norm_gini_val: 0.25875
#
# Epoch 00008: norm_gini_val did not improve from 0.25963
# Epoch 9/5000
#  - 79s - loss: 0.1526 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.6488 - roc_auc_val: 0.63022 - norm_gini: 0.2976 - norm_gini_val: 0.26045
#
# Epoch 00009: norm_gini_val improved from 0.25963 to 0.26045, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 10/5000
#  - 78s - loss: 0.1525 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.64949 - roc_auc_val: 0.63018 - norm_gini: 0.29898 - norm_gini_val: 0.26037
#
# Epoch 00010: norm_gini_val did not improve from 0.26045
# Epoch 11/5000
#  - 79s - loss: 0.1525 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65082 - roc_auc_val: 0.63073 - norm_gini: 0.30164 - norm_gini_val: 0.26145
#
# Epoch 00011: norm_gini_val improved from 0.26045 to 0.26145, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 12/5000
#  - 79s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65229 - roc_auc_val: 0.63065 - norm_gini: 0.30457 - norm_gini_val: 0.2613
#
# Epoch 00012: norm_gini_val did not improve from 0.26145
# Epoch 13/5000
#  - 78s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65342 - roc_auc_val: 0.63062 - norm_gini: 0.30683 - norm_gini_val: 0.26125
#
# Epoch 00013: norm_gini_val did not improve from 0.26145
# Epoch 14/5000
#  - 79s - loss: 0.1523 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65283 - roc_auc_val: 0.62971 - norm_gini: 0.30566 - norm_gini_val: 0.25943
#
# Epoch 00014: norm_gini_val did not improve from 0.26145
# Epoch 15/5000
#  - 78s - loss: 0.1522 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65303 - roc_auc_val: 0.63084 - norm_gini: 0.30607 - norm_gini_val: 0.26168
#
# Epoch 00015: norm_gini_val improved from 0.26145 to 0.26168, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 16/5000
#  - 79s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65582 - roc_auc_val: 0.63152 - norm_gini: 0.31164 - norm_gini_val: 0.26303
#
# Epoch 00016: norm_gini_val improved from 0.26168 to 0.26303, saving model to keras-5fold-run-01-v1-fold-04-run-02.check
# Epoch 17/5000
#  - 78s - loss: 0.1521 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.6576 - roc_auc_val: 0.63108 - norm_gini: 0.31521 - norm_gini_val: 0.26216
#
# Epoch 00017: norm_gini_val did not improve from 0.26303
# Epoch 18/5000
#  - 86s - loss: 0.1520 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65712 - roc_auc_val: 0.63102 - norm_gini: 0.31424 - norm_gini_val: 0.26204
#
# Epoch 00018: norm_gini_val did not improve from 0.26303
# Epoch 19/5000
#  - 78s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65794 - roc_auc_val: 0.63096 - norm_gini: 0.31587 - norm_gini_val: 0.26192
#
# Epoch 00019: norm_gini_val did not improve from 0.26303
# Epoch 20/5000
#  - 79s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1524 - val_acc: 0.9636
# roc_auc: 0.65887 - roc_auc_val: 0.63131 - norm_gini: 0.31775 - norm_gini_val: 0.26262
#
# Epoch 00020: norm_gini_val did not improve from 0.26303
# Epoch 21/5000
#  - 79s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.659 - roc_auc_val: 0.63035 - norm_gini: 0.318 - norm_gini_val: 0.2607
#
# Epoch 00021: norm_gini_val did not improve from 0.26303
# Epoch 22/5000
#  - 78s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.65925 - roc_auc_val: 0.63088 - norm_gini: 0.3185 - norm_gini_val: 0.26177
#
# Epoch 00022: norm_gini_val did not improve from 0.26303
# Epoch 23/5000
#  - 78s - loss: 0.1519 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9636
# roc_auc: 0.65951 - roc_auc_val: 0.63071 - norm_gini: 0.31902 - norm_gini_val: 0.26141
#
# Epoch 00023: norm_gini_val did not improve from 0.26303
# Epoch 24/5000
#  - 78s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1525 - val_acc: 0.9635
# roc_auc: 0.65964 - roc_auc_val: 0.63102 - norm_gini: 0.31927 - norm_gini_val: 0.26205
#
# Epoch 00024: norm_gini_val did not improve from 0.26303
# Epoch 25/5000
#  - 78s - loss: 0.1518 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9635
# roc_auc: 0.66062 - roc_auc_val: 0.6303 - norm_gini: 0.32125 - norm_gini_val: 0.2606
#
# Epoch 00025: norm_gini_val did not improve from 0.26303
# Epoch 26/5000
#  - 79s - loss: 0.1516 - acc: 0.9636 - val_loss: 0.1526 - val_acc: 0.9636
# roc_auc: 0.66086 - roc_auc_val: 0.62928 - norm_gini: 0.32172 - norm_gini_val: 0.25856
#
# Epoch 00026: norm_gini_val did not improve from 0.26303
# Epoch 00026: early stopping
#
#  Fold 4 Run 2 Log-loss: 0.15241
#  Fold 4 Run 2 AUC: 0.63152
#  Fold 4 Run 2 normalized gini: 0.26303
#
#  Fold 4 Log-loss: 0.15238
#  Fold 4 AUC: 0.63325
#  Fold 4 normalized gini: 0.26651
#
#  Time taken: 1 hours 59 minutes and 40.56 seconds.

# %% [markdown]
# Here we average all the predictions and provide the final summary.

# %%
LL_oof = log_loss(avreal, avpred)
print('\n Average Log-loss: %.5f' % (cv_LL/folds))
print(' Out-of-fold Log-loss: %.5f' % LL_oof)
AUC_oof = roc_auc_score(avreal, avpred)
print('\n Average AUC: %.5f' % (cv_AUC/folds))
print(' Out-of-fold AUC: %.5f' % AUC_oof)
print('\n Average normalized gini: %.5f' % (cv_gini/folds))
print(' Out-of-fold normalized gini: %.5f' % (AUC_oof*2-1))
score = str(round((AUC_oof*2-1), 5))
timer(starttime)
mpred = pred / folds
# Out:
#  Average Log-loss: 0.34292
#  Out-of-fold Log-loss: 0.15224
#
#  Average AUC: 1.42437
#  Out-of-fold AUC: 0.63438
#
#  Average normalized gini: 0.59874
#  Out-of-fold normalized gini: 0.26876
#
#  Time taken: 5 hours 56 minutes and 53.39 seconds.

# %% [markdown]
# Save the file with out-of-fold predictions. For easier book-keeping, file names have the out-of-fold gini score and are are tagged by date and time.

# %%
print('#\n Writing results')
now = datetime.now()
oof_result = pd.DataFrame(avreal, columns=['target'])
oof_result['prediction'] = avpred
oof_result['id'] = avids
oof_result.sort_values('id', ascending=True, inplace=True)
oof_result = oof_result.set_index('id')
sub_file = 'train_5fold-keras-run-01-v1-oof_' + str(score) + '_' + str(now.strftime('%Y-%m-%d-%H-%M')) + '.csv'
print('\n Writing out-of-fold file:  %s' % sub_file)
oof_result.to_csv(sub_file, index=True, index_label='id')
# Out:
# #
#  Writing results
#
#  Writing out-of-fold file:  train_5fold-keras-run-01-v1-oof_0.26876_2019-05-30-01-02.csv

# %% [markdown]
# Save the final prediction. This is the one to submit.

# %%
result = pd.DataFrame(mpred, columns=['target'])
result['id'] = te_ids
result = result.set_index('id')
print('\n First 10 lines of your 5-fold average prediction:\n')
print(result.head(10))
sub_file = 'submission_5fold-average-keras-run-01-v1_' + str(score) + '_' + str(now.strftime('%Y-%m-%d-%H-%M')) + '.csv'
print('\n Writing submission:  %s' % sub_file)
result.to_csv(sub_file, index=True, index_label='id')
# Out:
#  First 10 lines of your 5-fold average prediction:
#
#       target
# id
# 0   0.034712
# 1   0.026840
# 2   0.026046
# 3   0.016958
# 4   0.034355
# 5   0.042838
# 6   0.017382
# 8   0.026070
# 10  0.057547
# 11  0.036455
#
#  Writing submission:  submission_5fold-average-keras-run-01-v1_0.26876_2019-05-30-01-02.csv

# %% [markdown]
# ![](./porto/submit.png)
